# %% [markdown]
# **[DIABETES DATASET]**

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/archive (6).zip')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.shape
# Out:
# (768, 9)

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#creating graph for outcome column (how many people are got diabetes)
plt.bar(list(['safe','not-safe']),df['Outcome'].value_counts().values, color=['green','red'])
plt.show()

# %%
# understanding the BloodPreasure column by histogram
sns.histplot(df['BloodPressure'])
plt.plot()
# Out:
# []

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# histogram for Age column
sns.histplot(df['Age'])
plt.plot()
# Out:
# []

# %%
# Declaring independent variable(x) and dependent variable(y)
x = df[['Age']]
y = df[['Outcome']]

# %%
# spliting the data in to train , test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x ,y , test_size=0.3)

# %%
# import DecisionTreeRegressor and creat instance
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()

# %%
# fit training dataset dtr
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
# predict
y_pred = dtr.predict(x_test)

# %%
y_test.head()
# Out:
#      Outcome
# 572        0
# 399        1
# 31         1
# 440        1
# 739        1

# %%
y_pred[0:5]
# Out:
# array([0.16326531, 0.3030303 , 0.26923077, 0.57894737, 0.44444444])

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 0.19777457244425198

# %% [markdown]
# **DECISION TREE CLASSIFIER**

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x = df[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']]
y = df[['Outcome']]

# %%
from sklearn.model_selection import train_test_split
train_test_split(x ,y , test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()

# %%
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dtc.predict(x_test)

# %%
y_test.head()
# Out:
#      Outcome
# 572        0
# 399        1
# 31         1
# 440        1
# 739        1

# %%
y_pred[0:5]
# Out:
# array([0, 0, 0, 1, 0])

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[140,  17],
#        [ 51,  23]])

# %%
# Accuracy is left diagonal divided by all element in that matrix
Accuracy = (140+23)/(140+17+51+23)

# %%
Accuracy
# Out:
# 0.7056277056277056

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(30,10))
plot_tree(dtc, filled=True, feature_names=x.columns, class_names=['0', '1'])
plt.show()
